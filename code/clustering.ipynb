# %%
import pandas as pd
import psycopg2
from sklearn.externals import joblib
import numpy as np
import os

# %%
# this will be used when converted to real script to maintain ID ordering when we cluster and label 
# just need to change target table 

# conn = psycopg2.connect("dbname='cap' user='postgres' host='ec2-34-215-56-46.us-west-2.compute.amazonaws.com' port=9000 password ='secret'")
# data = pd.read_sql_query("SELECT * FROM nlp_dim_hpc ORDER BY id ASC", conn)


# going to try on a bunch of article bodies without NLP for performance
# data = pd.read_sql_query("SELECT * FROM articles ORDER BY id ASC", conn)

# data = pd.read_csv('nlp_dim_1000.csv')
data = pd.read_pickle('nlp_data.pkl')

# %%
# data.head()
data.info()
# data.to_pickle('nlp_data.pkl')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164541 entries, 0 to 164540
# Data columns (total 21 columns):
# index                 164541 non-null int64
# site                  164541 non-null object
# title                 164538 non-null object
# author                126494 non-null object
# published_on          130775 non-null object
# accessed_on           164541 non-null datetime64[ns]
# url                   164541 non-null object
# body                  164541 non-null object
# newspaper_keywords    164541 non-null object
# newspaper_summary     164541 non-null object
# id                    164541 non-null int64
# tokenized_body        164541 non-null object
# word_count            164541 non-null int64
# stopworded_body       164541 non-null object
# lemmatized_body       164541 non-null object
# word_bag              164541 non-null object
# named_entities        164541 non-null object
# lexical_diversity     164541 non-null float64
# sentiment_score       164541 non-null object
# binary_sentiment      164541 non-null int64
# cluster_label         164541 non-null int32
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(4), object(14)
# memory usage: 25.7+ MB

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer

# transforms data into tfidf matrix representation
vectorizer = TfidfVectorizer(max_df=0.5, max_features=num_features,
                                 min_df=2, use_idf=True)
if not os.path.exists('model'):
    os.makedirs('model')

joblib.dump(vectorizer, 'model/tf_vectorizer_obj.pkl')
# Out:
# ['model/tf_vectorizer_obj.pkl']

# %%
# define num features
num_features = 250

# %%
# fit our data (list of article bodies) to a tfidf representation
X = vectorizer.fit_transform(data.lemmatized_body)

# verify we have a sparse matrix of 100 tfidf features for each article 
# should be 5*100 sparse matrix
X
# Out:
# <164541x250 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9477063 stored elements in Compressed Sparse Row format>

# %%
# Store the data that we have of TFIDF vectors into a file
from scipy import sparse

# %%
sparse.save_npz('model/tf_idf.npz', X)

# %%
y = sparse.load_npz('model/tf_idf.npz')
y
# Out:
# <164541x250 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9477063 stored elements in Compressed Sparse Row format>

# %%
from sklearn.cluster import KMeans

# How many clusters we want
true_k = 15

# create the KMeans object with initial settings
km = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1,
                verbose=True)

# %%
# fit our tfidf data to the kmeans model
km.fit(X)
# Out:
# Initialization complete
# Iteration  0, inertia 207612.747
# Iteration  1, inertia 122592.830
# Iteration  2, inertia 119837.364
# Iteration  3, inertia 119053.751
# Iteration  4, inertia 118729.593
# Iteration  5, inertia 118592.674
# Iteration  6, inertia 118531.077
# Iteration  7, inertia 118501.895
# Iteration  8, inertia 118485.052
# Iteration  9, inertia 118470.576
# Iteration 10, inertia 118457.299
# Iteration 11, inertia 118444.748
# Iteration 12, inertia 118430.881
# Iteration 13, inertia 118414.126
# Iteration 14, inertia 118389.942
# Iteration 15, inertia 118353.273
# Iteration 16, inertia 118293.852
# Iteration 17, inertia 118211.742
order_centroids = km.cluster_centers_.argsort()[:, ::-1]
labels = km.labels_
print(terms)

# order_centroids

for i in range(3):
    for ind in order_centroids[i, :5]:
            print(' %s' % terms[ind], end='')
    print('\n')
# Out:
# ['000', '10', '2016', '2017', 'accord', 'add', 'administration', 'advertisement', 'allow', 'already', 'american', 'and', 'another', 'apple', 'around', 'as', 'ask', 'at', 'attack', 'away', 'back', 'base', 'become', 'begin', 'believe', 'best', 'big', 'bill', 'bring', 'build', 'business', 'call', 'campaign', 'car', 'case', 'change', 'child', 'city', 'claim', 'close', 'com', 'come', 'company', 'continue', 'could', 'country', 'court', 'create', 'data', 'day', 'de', 'deal', 'department', 'different', 'director', 'do', 'election', 'end', 'even', 'every', 'expect', 'face', 'facebook', 'family', 'far', 'federal', 'feel', 'find', 'fire', 'first', 'five', 'follow', 'for', 'force', 'former', 'four', 'game', 'give', 'good', 'google', 'government', 'great', 'group', 'happen', 'he', 'head', 'health', 'help', 'high', 'hold', 'home', 'house', 'if', 'image', 'include', 'information', 'issue', 'job', 'keep', 'kill', 'know', 'la', 'last', 'later', 'law', 'le', 'lead', 'leader', 'least', 'leave', 'less', 'life', 'line', 'little', 'live', 'long', 'look', 'lot', 'main', 'man', 'many', 'market', 'may', 'mean', 'medium', 'meet', 'member', 'might', 'million', 'money', 'month', 'move', 'mr', 'much', 'name', 'national', 'need', 'never', 'news', 'next', 'night', 'north', 'number', 'offer', 'office', 'official', 'old', 'on', 'open', 'order', 'part', 'party', 'pay', 'people', 'percent', 'phone', 'photo', 'place', 'plan', 'play', 'point', 'police', 'policy', 'political', 'post', 'power', 'president', 'problem', 'product', 'program', 'provide', 'public', 'put', 'question', 'read', 'really', 'release', 'report', 'republican', 'right', 'run', 'school', 'season', 'second', 'security', 'see', 'seem', 'service', 'set', 'share', 'she', 'show', 'sign', 'since', 'so', 'something', 'speak', 'star', 'start', 'state', 'statement', 'still', 'story', 'support', 'system', 'talk', 'tax', 'team', 'tell', 'that', 'there', 'they', 'thing', 'think', 'this', 'though', 'three', 'to', 'today', 'top', 'trump', 'try', 'turn', 'twitter', 'two', 'united', 'up', 'us', 'use', 'video', 'view', 'want', 'war', 'washington', 'watch', 'way', 'we', 'week', 'well', 'what', 'when', 'whether', 'white', 'without', 'woman', 'work', 'world', 'write', 'york', 'you']
#  2017 show star photo twitter
#
#  de la le advertisement 2017
#
#  company market million business car

# %%
# compare saved and loaded kmeans
kmeans_loaded = joblib.load('model/kmeans_model.pkl')

terms = vectorizer.get_feature_names()
order_centroids = kmeans_loaded.cluster_centers_.argsort()[:, ::-1]
labels = kmeans_loaded.labels_

# order_centroids

for i in range(15):
    print(i)
    for ind in order_centroids[i, :]:
            #print(i)
            print(' %s' % terms[ind], end='')
    print('\n')
# Out:
# 0
#  2017 show star photo twitter image first may video season com share post day two news last see 10 include come look story team week this he follow world tell today report back us we play home people million release night use family know find old best could medium accord work city 000 well month live three read write next second call watch and even around top car close start give end name still fire life on open york way since set for war high want man leave she run many you part right add statement place much four long big another help thing that child good if 2016 think expect as service become facebook house change line move begin to offer need plan there lead system school game deal phone continue point five head great former american national little white later turn they company view number woman sign though bring up keep away never member put face do pay every try create support country group ask build mean claim talk happen really already base might hold state far when what seem director business power at issue president so data la lot something feel without meet market force program least provide different official office case kill public less percent allow washington believe speak order bill north question job information whether money trump product problem attack united party police de political main advertisement health security mr court campaign leader google department policy law government apple federal election tax le administration republican
#
# 1
#  de la le advertisement 2017 google apple facebook twitter trump on 10 image come 2016 us 000 photo police york pay video com million post star may place city do face service he base force close information man part state question public plan show medium first point washington day party share call business play tell home leader main family old know accord people two for woman national we car president long see far at open house war week second report world live three since director right group continue news story look include administration back attack thing want watch follow work this read talk use start government end leave top best to high white last team could child so american night life even think head up deal and add happen run she keep many give good country court kill case set meet federal as official market phone game power next issue you around find bring fire bill today lead little away when hold political later view former office well name write claim line put great big department month much way support try sign election member four campaign build they might release become offer ask never still data though begin school provide mean there really statement different five need something what turn every change speak another company north feel believe move that lot job create help united money if mr least without allow whether season tax policy program percent number already problem republican seem system security order law health expect product less
#
# 2
#  company market million business car service use data percent product report share work include plan last 000 month system first we accord could us build deal well offer pay come help this expect people two may see next look world today start that need way provide number 10 continue still even and week high money around since part many end create call big change day 2017 want much add program give job back 2016 team move already google statement tell show group information base city power to three find as run lead long public open allow release close news set follow top issue point image post know home read on thing claim become far support york state security if for medium mean order government good problem another bring less phone think line write country right case begin put second best video twitter at there keep might though lot place name office without he com you so try different facebook five hold leave president story least former american they believe every apple sign head four whether health seem turn federal question really talk director view ask photo policy member face later little law something when live up court trump great away do department meet tax watch what bill happen game play life party force national fire never united house old official family north main feel woman mr leader campaign administration speak washington advertisement attack season star school she white political man child night la war election de kill police republican le
#
# 3
#  facebook company post news people medium election google twitter video use report share us million information we live story see group work political 000 data last show 2016 help campaign way include image tell could month this world find write accord photo business service call create week today want read may come public first need add look allow issue day know and well product follow many trump even give you think try problem around number thing part build next that run place two still question ask police provide pay change if american statement state right team much 2017 government become policy for whether plan start law already percent another view might offer on he continue mean they back seem old every order since keep far face claim system country to top set support 10 family open as watch phone talk something big there kill game good bring money release turn security point head three happen attack lead life feel member long believe lot man leave put market different base though name what expect president so com child when deal case party move woman without end house really york less play do best she begin advertisement later high least at power job sign up little meet second former hold home close court washington never speak line mr away four director white main program school apple official force city national united leader bill office great fire five federal republican night department war car health la star de north le season tax administration
#
# 4
#  game season play team first point run he two second three back start last night best come lead world four 2017 look we and home that way week right well even end good give think could today know five see thing leave want 10 still big much star this day next you need they national since top may really photo use com put twitter state lot work great every show follow try if head another line move video feel around there keep include little find though long close for watch washington might set us open high turn tell seem call never help something city far so part many old allow become away man system as base add face release on different happen story without mean to power place share people read post when expect change talk continue already do york least hold month at million ask company later number bring begin sign build 2016 up create what support deal life former question force live name less job offer percent plan court accord whether report image issue pay believe fire problem case war medium news group write school provide official 000 family american president attack program meet order statement money north speak market view service country la bill member claim party facebook united main white business car campaign kill data product phone google leader advertisement director child trump house information office woman public she health de police apple policy political mr security law department government federal le tax election republican administration
#
# 5
#  apple google phone company use home work product look still well see system first even video report could come include service watch this data support next release thing market want people start way and last play need show much you photo two may add us today that back we offer if find around give build might call face pay 10 run million already best though share month percent seem change top issue big case many image world expect mean know accord week business day read help information create set good there right different car without end allow plan number 2017 news to for lot on problem as since power high point turn try something part really open think less keep far line order tell long post so view another facebook every little put security base three move bring great provide life claim game twitter place at ask follow live feel least program team 2016 later second name deal 000 whether com become do story job talk party leave continue begin when hold write what question close lead money court they old head away believe happen sign four never statement up state public five medium white he country fire speak group main york force family official office president attack government house policy city woman meet health school federal star former department director trump law night member war american police campaign tax advertisement united child bill la national man washington leader mr kill season election she political de administration north le republican
#
# 11
#  people and know use work think thing want life way find come see we even look he could you day really well first us much need tell world this feel good if back help two something that many they show give still start there lot so might around live right she home may change family try every call when child play little write long story never best become do old keep part different mean for place great what as end talk ask school seem put happen last turn point to leave set team three another big read run high create though next include system open week without add move problem less watch today man on away since city name image american job 10 money phone month share follow begin 000 build question business case lead bring night woman power health offer far second company line head believe at group face star pay whether car video already four number country news later top photo post plan house speak state five allow white close least million york hold support meet deal issue provide percent accord continue season game facebook data view base medium product service sign twitter up report director order war expect release 2017 kill information program public market member national force com claim fire president former office main party 2016 bill trump government attack political washington law north google security united la apple police leader de statement policy campaign mr advertisement official department court tax administration federal election republican le
#
# 12
#  woman she tell story people work report come know write york news think and speak many first want man show he company find two twitter include statement life post call ask we day see way claim feel child medium old even right give thing world could 2017 use never us follow image share accord case family leave star look this director week last power change help need read may back former become you well face they try happen when talk another three photo issue facebook name state part police live really there american white still since that public add something health believe long continue as if on group around month meet start bill trump for much do every pay later support president good job country percent force place law what video begin play put set number night home lot problem school lead open member point 000 business high to release without five court away keep today fire question office different campaign million seem end turn less city mean mr though so watch might party bring run best close hold advertisement least little sign team house whether com offer plan up head attack at 2016 national create 10 political move next allow far four top second view provide big war line kill service money deal washington great order policy department expect government base already official information leader product united program game election system main phone car build data season north federal de la security administration republican market google apple tax le
#
# 13
#  police attack kill man report he people tell old department two accord city car find family fire home state video call woman child news case court statement we law official leave day three know release security may night school she show use 2017 later come group believe life twitter photo last office force follow image member they public face see could around medium right facebook include try work first ask post back place run information another white hold happen claim us head four month live help week 000 york away com want 10 begin name country add lead la service still this government second least give there open on federal continue think since at high read even house national look speak close many whether five issue north part former question story turn sign president write mr number start share never when order way watch and support for phone set trump end put american without move point need up as well plan that today provide long keep 2016 party team bring become play washington world next something far meet talk you lot expect leader allow good thing change do political line business pay what united offer view policy every if election though little million advertisement job really much money de so company might feel build best problem already mean system bill health to director top deal less base star campaign main market game different power great war data seem create percent program big administration le republican season product tax google apple
#
# 14
#  party election republican campaign president trump political leader house bill state le government people former may national right country he support percent run member health news tell call last could first week come policy group american issue think two and want we work 2016 office change leave back report power even washington many day law lead plan see give hold need public far white know since include twitter court show point month medium become face us talk million ask next well 2017 question she follow way this sign official add tax use much that attack believe continue deal speak end 000 for they post try move money if write statement part still whether claim read look accord image help put long mr second thing world there system up woman expect view federal old war place security on job today open another three find as allow number turn force top director pay close set mean do so head keep meet never business good story you night what name city administration around every line already begin seem bring later united without high though five share start play less might big facebook happen 10 life problem great north four base really market york at case advertisement police family to something live lot create when photo order least release company offer away watch com home provide fire man main service little different school program best information feel data child team video department build kill de la star game phone season car product google apple

# %%
# Small test for how we can eventually persist the cluster labels for individual articles
# Since the labels attribute is in the order that the sparse matrix was in when it was passed in
# We should be able just insert the label value as a dataframe column

t = pd.Series(labels)
data['cluster_label'] = t
# data

# %%
tfidf = TfidfVectorizer(max_features=num_features)
X_test = tfidf.fit_transform([data.lemmatized_body[200]])

# %%
z = km.predict(X_test)
print(z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-db99a25b3551> in <module>()
# ----> 1 z = km.predict(X_test)
#       2 print(z)
#
# c:\users\thefl\appdata\local\programs\python\python36\lib\site-packages\sklearn\cluster\k_means_.py in predict(self, X)
#     986         check_is_fitted(self, 'cluster_centers_')
#     987
# --> 988         X = self._check_test_data(X)
#     989         x_squared_norms = row_norms(X, squared=True)
#     990         return _labels_inertia(X, x_squared_norms, self.cluster_centers_)[0]
#
# c:\users\thefl\appdata\local\programs\python\python36\lib\site-packages\sklearn\cluster\k_means_.py in _check_test_data(self, X)
#     869             raise ValueError("Incorrect number of features. "
#     870                              "Got %d features, expected %d" % (
# --> 871                                  n_features, expected_n_features))
#     872
#     873         return X
#
# ValueError: Incorrect number of features. Got 126 features, expected 250

# %%
data.sort_values('cluster_label')
# Out:
#         index             site  \
# 62246     250              FOX
# 81906      67   WashingtonPost
# 81911      72   WashingtonPost
# 126119     92  BusinessInsider
# 29425      93      Arstechnica
# 139377    328         Guardian
# 119878    364         USAToday
# 81923      84   WashingtonPost
# 139373    324         Guardian
# 29416      84      Arstechnica
# 29415      83      Arstechnica
# 29412      80      Arstechnica
# 81935      96   WashingtonPost
# 81951     112   WashingtonPost
# 139357    308         Guardian
# 119870    356         USAToday
# 139350    301         Guardian
# 29399      67      Arstechnica
# 29398      66      Arstechnica
# 29395      63      Arstechnica
# 29394      62      Arstechnica
# 119869    355         USAToday
# 119868    354         USAToday
# 139342    293         Guardian
# 29387      55      Arstechnica
# 81986     147         Guardian
# 29383      51      Arstechnica
# 81993     154         Guardian
# 139336    287         Guardian
# 82004     165         Guardian
# ...       ...              ...
# 52708     450            Yahoo
# 52687     429            Yahoo
# 99395     421             Time
# 147960    967         Atlantic
# 158027      5       GoogleNews
# 99397     423         Atlantic
# 147963    970         Atlantic
# 99399     425         Atlantic
# 147967    974         Atlantic
# 133239    199      Arstechnica
# 133237    197      Arstechnica
# 99405     431         Atlantic
# 99408     434         Atlantic
# 99410     436         Atlantic
# 99412     438         Atlantic
# 99413     439         Atlantic
# 99416     442         Atlantic
# 99418     444         Atlantic
# 128042    512         Atlantic
# 128043    513         Atlantic
# 158008    986            Yahoo
# 99420     446         Atlantic
# 133224    184      Arstechnica
# 99425     451         Atlantic
# 158004    982            Yahoo
# 99426     452         Atlantic
# 99429     455         Atlantic
# 147992    999         Atlantic
# 21379      62      Arstechnica
# 41664     100        Breitbart
#
#                                                     title  \
# 62246   Tourists keep returning 'cursed' lava rocks to...
# 81906   Ariana Grande announces ‘One Love Manchester’ ...
# 29395   Samsung's newest Android flagship, the Galaxy ...
# 29394   It's been a fun 13 weeks, but the second seaso...
# 119869  Skip in Skip x Embed x Share CLOSE Former host...
# 119868  Skip in Skip x Embed x Share CLOSE When a coll...
# 139342  Precourt Sports Ventures Considering Relocatio...
# 29387   Antivirus provider Webroot is causing a world ...
# 81986   The death of her older sister from brain cance...
# 29383   In 1882, the world's first coal-fired public-u...
# 81993   The five leaders mock the notorious photo and ...
# 139336  This new Thor film delivers a hammer-blow of b...
# 82004   Puzzling tweet by US president late at night l...
# ...                                                   ...
# 52708   Labour leader Jeremy Corbyn on the general ele...
# 52687   Labour leader Jeremy Corbyn on the general ele...
# 99395   California Governor-elect Jerry Brown speaks d...
# 147960  Only a country with as much going for it as th...
# 158027  Truth rating: 1  By Shari Weiss |  Kris Jenner...
# 99397   BERLIN (Reuters) - German Chancellor Angela Me...
# 147963  WASHINGTON (AP) — A firm run by Donald Trump's...
# 99399   PARIS — Martin Schulz, the Social Democrat can...
# 147967  Nobody knows how Monday’s indictment of Paul M...
# 133239  A bipartisan group of federal lawmakers wants ...
# 133237  A bipartisan group of federal lawmakers wants ...
# 99405   Charlie Dent’s nightmare began 28 months ago, ...
# 99408   French President Emmanuel Macron’s ambitious p...
# 99410   These are ulcer-inducing times for moderate Re...
# 99412   BERLIN (Reuters) - German Chancellor Angela Me...
# 99413   These are ulcer-inducing times for moderate Re...
# 99416   These are ulcer-inducing times for moderate Re...
# 99418   In a long speech on September 23, Emmanuel Mac...
# 128042  The former president reprised his favorite the...
# 128043  When Shinzo Abe, the prime minister of Japan, ...
# 158008  Watch news, TV and more on Yahoo View.    WASH...
# 99420   In a long speech on September 23, Emmanuel Mac...
# 133224  After the Soviet Union flew the Sputnik 1 sate...
# 99425   In a long speech on September 23, Emmanuel Mac...
# 158004  FILE - In this Monday, Oct. 23, 2017, file pho...
# 99426   In a long speech on September 23, Emmanuel Mac...
# 99429   French President Emmanuel Macron called for a ...
# 147992  Paul Manafort, who reportedly was a recipient ...
# 21379   Prime minister Theresa May has called for a sn...
# 41664   SIGN UP FOR OUR NEWSLETTER  Senate Minority Le...
#
#                                        newspaper_keywords  \
# 62246   {visitors,national,tourists,hawaii,legend,volc...
# 81906   {grande,katy,benefit,announces,love,bieber,liv...
# 81911   {chance,possible,low,forecast,storms,tomorrow,...
# 126119  {ad,rock,city,arkansas,little,amazons,chamber,...
# 29425   {ship,season,crew,protomolecule,expanse,scene,...
# 139377  {america,club,precourt,city,fans,whim,1000,sta...
# 119878  {star,google,music,quintanilla,debut,x,wrote,s...
# 81923   {rick,foucheux,henley,design,king,meltdown,reg...
# 139373  {ditched,fox,host,television,trumps,nbc,mistak...
# 29416   {silicon,richard,repetition,season,seasons,com...
# 29415   {nukes,quarantined,legit,ars,24,system,files,o...
# 29412   {samsung,fix,red,promises,white,balance,adjust...
# 81935   {hiding,darrell,district,2018,ask,levin,issas,...
# 81951   {million,residential,prince,suite,st,masterbed...
# 139357  {youve,135,abv,reserva,wine,drinkers,gran,trad...
# 119870  {babysitting,planet,things,beckham,giants,popu...
# 139350  {hand,president,assault,issues,spokesman,sexua...
# 29399   {fourth,silicon,richard,season,seasons,company...
# 29398   {ship,season,crew,protomolecule,expanse,scene,...
# 29395   {samsung,fix,red,promises,white,balance,adjust...
# 29394   {ship,season,protomolecule,expanse,scene,war,d...
# 119869  {daughter,wife,rushed,email,children,family,ca...
# 119868  {halloween,watch,series,weird,horror,king,x,fe...
# 139342  {options,precourt,ventures,stadium,sc,columbus...
# 29387   {nukes,quarantined,legit,24,windows,files,offi...
# 81986   {sky,newtonjohns,newtonjohn,review,stage,niels...
# 29383   {solar,plants,gas,uk,revolution,industrial,gri...
# 81993   {orb,nordic,prime,trumps,social,ministers,lead...
# 139336  {world,usual,thor,malekith,wicked,loki,wit,pla...
# 82004   {president,trumps,russian,late,baffles,night,k...
# ...                                                   ...
# 52708   {accused,backlash,corbyns,jeremy,britain,manif...
# 52687   {accused,backlash,corbyns,jeremy,britain,manif...
# 99395   {penalty,hiv,bill,republican,brown,times,expos...
# 147960  {legislative,balance,republican,united,broken,...
# 158027  {inviting,middleton,kris,christmas,jenner,kate...
# 99397   {faces,macrons,asylum,chastened,pressure,merke...
# 147963  {lobbying,gates,washington,campaign,advisers,p...
# 99399   {forget,president,man,french,schulz,merkel,eur...
# 147967  {kleptocracy,ukraine,money,kiev,political,coun...
# 133239  {ads,russia,online,legislation,russian,politic...
# 133237  {ads,russia,online,legislation,russian,politic...
# 99405   {president,trump,republican,group,house,dents,...
# 99408   {reaction,coalition,proposals,macrons,division...
# 99410   {republicans,republican,hes,moderates,house,de...
# 99412   {faces,macrons,asylum,chastened,pressure,merke...
# 99413   {republicans,republican,hes,moderates,house,de...
# 99416   {republicans,republican,hes,moderates,house,de...
# 99418   {reform,merkel,europe,eurozone,macron,save,ger...
# 128042  {message,america,president,trail,unity,trumps,...
# 128043  {polls,abe,elections,party,support,abes,winnin...
# 158008  {brazile,thought,president,wanted,writes,clint...
# 99420   {reform,merkel,europe,eurozone,macron,save,ger...
# 133224  {fly,jing,member,chinese,seeks,space,loyalty,p...
# 99425   {reform,merkel,europe,eurozone,macron,save,ger...
# 158004  {hong,prison,chinese,anthem,kong,legislature,c...
# 99426   {reform,merkel,europe,eurozone,macron,save,ger...
# 99429   {backs,macrons,budget,idea,finance,merkel,euro...
# 147992  {strongman,president,ukraine,manaforts,ukraini...
# 21379   {general,theresa,vote,need,election,wants,vowe...
# 41664   {work,trump,schumer,role,worked,president,nego...
#
#                                         newspaper_summary      ...        \
# 62246   It may seem like a harmless souvenir, tucking ...      ...
# 81906   Ariana Grande performs on NBC’s “Today” show i...      ...
# 81911   5/10: Same old story with more showers possibl...      ...
# 126119  Little Rock, Arkansas, announced in an ad Thur...      ...
# 29425   It's been a fun 13 weeks, but the second seaso...      ...
# 139377  Coming off the United States’ failure to quali...      ...
# 119878  Skip in Skip x Embed x Share CLOSE Selena Quin...      ...
# 81923   The cracking kingdom is not a particularly big...      ...
# 139373  One year ago, Megyn Kelly was on top of the wo...      ...
# 29416   Further Reading Silicon Valley turns dark as i...      ...
# 29415   A signature update just nuked hundreds of beni...      ...
# 29412   As the device trickled out to users, some cust...      ...
# 81935   Rep. Darrell Issa (R-Calif.) was photographed ...      ...
# 81951   The four-bedroom, four-bathroom Colonial-Reviv...      ...
# 139357  If you don’t see the words reserva or gran res...      ...
# 119870  With his season-ending leg injury, Giants rece...      ...
# 139350  “To anyone he has offended, President Bush apo...      ...
# 29399   Note: Silicon Valley season four airs in the U...      ...
# 29398   It's been a fun 13 weeks, but the second seaso...      ...
# 29395   As the device trickled out to users, some cust...      ...
# 29394   It's been a fun 13 weeks, but the second seaso...      ...
# 119869  Skip in Skip x Embed x Share CLOSE Former host...      ...
# 119868  Skip in Skip x Embed x Share CLOSE When a coll...      ...
# 139342  Precourt Sports Ventures Considering Relocatio...      ...
# 29387   A signature update just nuked hundreds of beni...      ...
# 81986   A collaboration with Canadian singer Amy Sky a...      ...
# 29383   On Friday, some 135 years, a few monarchs, and...      ...
# 81993   The five leaders mock the notorious photo and ...      ...
# 139336  This new Thor film delivers a hammer-blow of b...      ...
# 82004   Just after midnight in Washington, Donald Trum...      ...
# ...                                                   ...      ...
# 52708   Labour leader Jeremy Corbyn on the general ele...      ...
# 52687   Labour leader Jeremy Corbyn on the general ele...      ...
# 99395   California Governor-elect Jerry Brown speaks d...      ...
# 147960  Almost every circumstance of today’s United St...      ...
# 158027  Truth rating: 1By Shari Weiss |Kris Jenner is ...      ...
# 99397   BERLIN (Reuters) - German Chancellor Angela Me...      ...
# 147963  Trump shook up his campaign's organization aga...      ...
# 99399   PARIS — Martin Schulz, the Social Democrat can...      ...
# 147967  But Mueller’s filings stand on their own as an...      ...
# 133239  A bipartisan group of federal lawmakers wants ...      ...
# 133237  A bipartisan group of federal lawmakers wants ...      ...
# 99405   And in a subtle acknowledgment of his group’s ...      ...
# 99408   The reaction said as much about the current st...      ...
# 99410   These are ulcer-inducing times for moderate Re...      ...
# 99412   BERLIN (Reuters) - German Chancellor Angela Me...      ...
# 99413   These are ulcer-inducing times for moderate Re...      ...
# 99416   These are ulcer-inducing times for moderate Re...      ...
# 99418   “For Europe we need a vision and a screwdriver...      ...
# 128042  The former president reprised his favorite the...      ...
# 128043  When Shinzo Abe, the prime minister of Japan, ...      ...
# 158008  WASHINGTON (AP) — The former head of the Democ...      ...
# 99420   “For Europe we need a vision and a screwdriver...      ...
# 133224  This association has led some members of Congr...      ...
# 99425   “For Europe we need a vision and a screwdriver...      ...
# 158004  On Saturday, Nov. 4, 2017, China's rubber-stam...      ...
# 99426   “For Europe we need a vision and a screwdriver...      ...
# 99429   Merkel backing for EU finance ministerPart of ...      ...
# 147992  Manafort’s years in Ukraine have come under re...      ...
# 21379   Prime minister Theresa May has called for a sn...      ...
# 41664   SIGN UP FOR OUR NEWSLETTERSenate Minority Lead...      ...
#
#                                            tokenized_body word_count  \
# 62246   {It,may,seem,like,a,harmless,souvenir,",",tuck...        345
# 81906   {Ariana,Grande,performs,on,NBC,’,s,“,Today,”,s...        337
# 81911   {TODAY,’,S,DAILY,DIGIT,A,somewhat,subjective,r...        532
# 126119  {Amazon,is,accepting,bids,from,cities,to,host,...        478
# 29425   {It,'s,been,a,fun,13,weeks,",",but,the,second,...        532
# 139377  {Coming,off,the,United,States,’,failure,to,qua...       1564
# 119878  {Skip,in,Skip,x,Embed,x,Share,CLOSE,Selena,Qui...        356
# 81923   {The,cracking,kingdom,is,not,a,particularly,bi...        842
# 139373  {One,year,ago,",",Megyn,Kelly,was,on,top,of,th...       1375
# 29416   {Stop,me,if,you,'ve,heard,this,one,before,:,on...        798
# 29415   {Antivirus,provider,Webroot,is,causing,a,world...        404
# 29412   {Samsung,'s,newest,Android,flagship,",",the,Ga...        430
# 81935   {Rep.,Darrell,Issa,(,R-Calif.,),was,photograph...        761
# 81951   {The,four-bedroom,",",four-bathroom,Colonial-R...        276
# 139357  {Wine,makers,are,having,to,prove,their,mettle,...        586
# 119870  {With,his,season-ending,leg,injury,",",Giants,...        227
# 139350  {Jordana,Grolnick,tells,Deadspin,that,the,form...        881
# 29399   {Note,:,Silicon,Valley,season,four,airs,in,the...        822
# 29398   {It,'s,been,a,fun,13,weeks,",",but,the,second,...        532
# 29395   {Samsung,'s,newest,Android,flagship,",",the,Ga...        430
# 29394   {It,'s,been,a,fun,13,weeks,",",but,the,second,...        526
# 119869  {Skip,in,Skip,x,Embed,x,Share,CLOSE,Former,hos...        552
# 119868  {Skip,in,Skip,x,Embed,x,Share,CLOSE,When,a,col...       1520
# 139342  {Precourt,Sports,Ventures,Considering,Relocati...        524
# 29387   {Antivirus,provider,Webroot,is,causing,a,world...        398
# 81986   {The,death,of,her,older,sister,from,brain,canc...        295
# 29383   {In,1882,",",the,world,'s,first,coal-fired,pub...        608
# 81993   {The,five,leaders,mock,the,notorious,photo,and...        333
# 139336  {This,new,Thor,film,delivers,a,hammer-blow,of,...        248
# 82004   {Puzzling,tweet,by,US,president,late,at,night,...        802
# ...                                                   ...        ...
# 52708   {Labour,leader,Jeremy,Corbyn,on,the,general,el...        696
# 52687   {Labour,leader,Jeremy,Corbyn,on,the,general,el...        696
# 99395   {California,Governor-elect,Jerry,Brown,speaks,...        560
# 147960  {Only,a,country,with,as,much,going,for,it,as,t...        584
# 158027  {Truth,rating,:,1,By,Shari,Weiss,|,Kris,Jenner...        506
# 99397   {BERLIN,(,Reuters,),-,German,Chancellor,Angela...        680
# 147963  {WASHINGTON,(,AP,),—,A,firm,run,by,Donald,Trum...        969
# 99399   {PARIS,—,Martin,Schulz,",",the,Social,Democrat...       1275
# 147967  {Nobody,knows,how,Monday,’,s,indictment,of,Pau...       1073
# 133239  {A,bipartisan,group,of,federal,lawmakers,wants...        459
# 133237  {A,bipartisan,group,of,federal,lawmakers,wants...        465
# 99405   {Charlie,Dent,’,s,nightmare,began,28,months,ag...       3710
# 99408   {French,President,Emmanuel,Macron,’,s,ambitiou...       1032
# 99410   {These,are,ulcer-inducing,times,for,moderate,R...        899
# 99412   {BERLIN,(,Reuters,),-,German,Chancellor,Angela...        680
# 99413   {These,are,ulcer-inducing,times,for,moderate,R...        899
# 99416   {These,are,ulcer-inducing,times,for,moderate,R...        899
# 99418   {In,a,long,speech,on,September,23,",",Emmanuel...       1707
# 128042  {The,former,president,reprised,his,favorite,th...       1032
# 128043  {When,Shinzo,Abe,",",the,prime,minister,of,Jap...        997
# 158008  {Watch,news,",",TV,and,more,on,Yahoo,View,.,WA...        362
# 99420   {In,a,long,speech,on,September,23,",",Emmanuel...       1707
# 133224  {After,the,Soviet,Union,flew,the,Sputnik,1,sat...        375
# 99425   {In,a,long,speech,on,September,23,",",Emmanuel...       1707
# 158004  {FILE,-,In,this,Monday,",",Oct.,23,",",2017,",...        632
# 99426   {In,a,long,speech,on,September,23,",",Emmanuel...       1707
# 99429   {French,President,Emmanuel,Macron,called,for,a...        758
# 147992  {Paul,Manafort,",",who,reportedly,was,a,recipi...       3313
# 21379   {Prime,minister,Theresa,May,has,called,for,a,s...        454
# 41664   {SIGN,UP,FOR,OUR,NEWSLETTER,Senate,Minority,Le...        320
#
#                                           stopworded_body  \
# 62246   {it,may,seem,like,harmless,souvenir,tucking,la...
# 81906   {ariana,grande,performs,nbc,’,“,today,”,show,2...
# 81911   {today,’,s,daily,digit,a,somewhat,subjective,r...
# 126119  {amazon,accepting,bids,cities,host,second,head...
# 29425   {it,fun,13,weeks,second,season,the,expanse,fin...
# 139377  {coming,united,states,’,failure,qualify,2018,w...
# 119878  {skip,skip,x,embed,x,share,close,selena,quinta...
# 81923   {the,cracking,kingdom,particularly,big,deal,“,...
# 139373  {one,year,ago,megyn,kelly,top,world,her,nightl...
# 29416   {stop,heard,one,:,silicon,valley,show,main,cha...
# 29415   {antivirus,provider,webroot,causing,world,trou...
# 29412   {samsung,newest,android,flagship,galaxy,s8,lau...
# 81935   {rep.,darrell,issa,r-calif.,photographed,atop,...
# 81951   {the,four-bedroom,four-bathroom,colonial-reviv...
# 139357  {wine,makers,prove,mettle,catering,tastebuds,n...
# 119870  {with,season-ending,leg,injury,giants,receiver...
# 139350  {jordana,grolnick,tells,deadspin,former,presid...
# 29399   {note,:,silicon,valley,season,four,airs,uk,sky...
# 29398   {it,fun,13,weeks,second,season,the,expanse,fin...
# 29395   {samsung,newest,android,flagship,galaxy,s8,lau...
# 29394   {it,fun,13,weeks,second,season,the,expanse,fin...
# 119869  {skip,skip,x,embed,x,share,close,former,hostag...
# 119868  {skip,skip,x,embed,x,share,close,when,college,...
# 139342  {precourt,sports,ventures,considering,relocati...
# 29387   {antivirus,provider,webroot,causing,world,trou...
# 81986   {the,death,older,sister,brain,cancer,2013,star...
# 29383   {in,1882,world,first,coal-fired,public-use,pow...
# 81993   {the,five,leaders,mock,notorious,photo,post,so...
# 139336  {this,new,thor,film,delivers,hammer-blow,bored...
# 82004   {puzzling,tweet,us,president,late,night,leads,...
# ...                                                   ...
# 52708   {labour,leader,jeremy,corbyn,general,election,...
# 52687   {labour,leader,jeremy,corbyn,general,election,...
# 99395   {california,governor-elect,jerry,brown,speaks,...
# 147960  {only,country,much,going,united,states—scale,r...
# 158027  {truth,rating,:,1,by,shari,weiss,|,kris,jenner...
# 99397   {berlin,reuters,german,chancellor,angela,merke...
# 147963  {washington,ap,—,a,firm,run,donald,trump,campa...
# 99399   {paris,—,martin,schulz,social,democrat,candida...
# 147967  {nobody,knows,monday,’,indictment,paul,manafor...
# 133239  {a,bipartisan,group,federal,lawmakers,wants,ma...
# 133237  {a,bipartisan,group,federal,lawmakers,wants,ma...
# 99405   {charlie,dent,’,nightmare,began,28,months,ago,...
# 99408   {french,president,emmanuel,macron,’,ambitious,...
# 99410   {these,ulcer-inducing,times,moderate,republica...
# 99412   {berlin,reuters,german,chancellor,angela,merke...
# 99413   {these,ulcer-inducing,times,moderate,republica...
# 99416   {these,ulcer-inducing,times,moderate,republica...
# 99418   {in,long,speech,september,23,emmanuel,macron,p...
# 128042  {the,former,president,reprised,favorite,themes...
# 128043  {when,shinzo,abe,prime,minister,japan,called,l...
# 158008  {watch,news,tv,yahoo,view,washington,ap,—,the,...
# 99420   {in,long,speech,september,23,emmanuel,macron,p...
# 133224  {after,soviet,union,flew,sputnik,1,satellite,1...
# 99425   {in,long,speech,september,23,emmanuel,macron,p...
# 158004  {file,in,monday,oct.,23,2017,file,photo,visito...
# 99426   {in,long,speech,september,23,emmanuel,macron,p...
# 99429   {french,president,emmanuel,macron,called,multi...
# 147992  {paul,manafort,reportedly,recipient,$,12.7m,uk...
# 21379   {prime,minister,theresa,may,called,snap,genera...
# 41664   {sign,up,for,our,newsletter,senate,minority,le...
#
#                                           lemmatized_body  \
# 62246   {it,may,seem,like,harmless,souvenir,tuck,lava,...
# 81906   {ariana,grande,performs,nbc,’,“,today,”,show,2...
# 81911   {today,’,s,daily,digit,a,somewhat,subjective,r...
# 126119  {amazon,accept,bid,city,host,second,headquarte...
# 29425   {it,fun,13,week,second,season,the,expanse,fina...
# 139377  {come,united,state,’,failure,qualify,2018,worl...
# 119878  {skip,skip,x,embed,x,share,close,selena,quinta...
# 81923   {the,cracking,kingdom,particularly,big,deal,“,...
# 139373  {one,year,ago,megyn,kelly,top,world,her,nightl...
# 29416   {stop,heard,one,:,silicon,valley,show,main,cha...
# 29415   {antivirus,provider,webroot,cause,world,troubl...
# 29412   {samsung,newest,android,flagship,galaxy,s8,lau...
# 81935   {rep.,darrell,issa,r-calif.,photographed,atop,...
# 81951   {the,four-bedroom,four-bathroom,colonial-reviv...
# 139357  {wine,maker,prove,mettle,catering,tastebuds,ne...
# 119870  {with,season-ending,leg,injury,giant,receiver,...
# 139350  {jordana,grolnick,tell,deadspin,former,preside...
# 29399   {note,:,silicon,valley,season,four,air,uk,sky,...
# 29398   {it,fun,13,week,second,season,the,expanse,fina...
# 29395   {samsung,newest,android,flagship,galaxy,s8,lau...
# 29394   {it,fun,13,week,second,season,the,expanse,fina...
# 119869  {skip,skip,x,embed,x,share,close,former,hostag...
# 119868  {skip,skip,x,embed,x,share,close,when,college,...
# 139342  {precourt,sport,venture,consider,relocation,co...
# 29387   {antivirus,provider,webroot,cause,world,troubl...
# 81986   {the,death,older,sister,brain,cancer,2013,star...
# 29383   {in,1882,world,first,coal-fired,public-use,pow...
# 81993   {the,five,leader,mock,notorious,photo,post,soc...
# 139336  {this,new,thor,film,delivers,hammer-blow,bored...
# 82004   {puzzle,tweet,us,president,late,night,lead,nat...
# ...                                                   ...
# 52708   {labour,leader,jeremy,corbyn,general,election,...
# 52687   {labour,leader,jeremy,corbyn,general,election,...
# 99395   {california,governor-elect,jerry,brown,speaks,...
# 147960  {only,country,much,go,united,states—scale,reso...
# 158027  {truth,rating,:,1,by,shari,weiss,|,kris,jenner...
# 99397   {berlin,reuters,german,chancellor,angela,merke...
# 147963  {washington,ap,—,a,firm,run,donald,trump,campa...
# 99399   {paris,—,martin,schulz,social,democrat,candida...
# 147967  {nobody,know,monday,’,indictment,paul,manafort...
# 133239  {a,bipartisan,group,federal,lawmaker,want,make...
# 133237  {a,bipartisan,group,federal,lawmaker,want,make...
# 99405   {charlie,dent,’,nightmare,begin,28,month,ago,c...
# 99408   {french,president,emmanuel,macron,’,ambitious,...
# 99410   {these,ulcer-inducing,time,moderate,republican...
# 99412   {berlin,reuters,german,chancellor,angela,merke...
# 99413   {these,ulcer-inducing,time,moderate,republican...
# 99416   {these,ulcer-inducing,time,moderate,republican...
# 99418   {in,long,speech,september,23,emmanuel,macron,p...
# 128042  {the,former,president,reprise,favorite,theme,h...
# 128043  {when,shinzo,abe,prime,minister,japan,call,low...
# 158008  {watch,news,tv,yahoo,view,washington,ap,—,the,...
# 99420   {in,long,speech,september,23,emmanuel,macron,p...
# 133224  {after,soviet,union,fly,sputnik,1,satellite,19...
# 99425   {in,long,speech,september,23,emmanuel,macron,p...
# 158004  {file,in,monday,oct.,23,2017,file,photo,visito...
# 99426   {in,long,speech,september,23,emmanuel,macron,p...
# 99429   {french,president,emmanuel,macron,call,multi-s...
# 147992  {paul,manafort,reportedly,recipient,$,12.7m,uk...
# 21379   {prime,minister,theresa,may,call,snap,general,...
# 41664   {sign,up,for,our,newsletter,senate,minority,le...
#
#                                                  word_bag  \
# 62246   {"(``,7)","('',7)","(rock,6)","(park,5)","(ret...
# 81906   {"(“,7)","(”,7)","(grande,7)","(manchester,6)"...
# 81911   {"(:,17)","(low,11)","(shower,11)","(confidenc...
# 126119  {"(amazon,12)","(city,11)","(rock,7)","(little...
# 29425   {"(i,8)","(subscribe,5)","(season,5)","(us,5)"...
# 139377  {"(’,33)","(move,16)","(the,15)","(ml,14)","(t...
# 119878  {"(selena,10)","(first,4)","(music,4)","(campo...
# 81923   {"(’,22)","(foucheux,10)","(lear,10)","(play,6...
# 139373  {"(’,37)","(kelly,30)","(one,11)","(morning,10...
# 29416   {"(``,11)","('',11)","(richard,9)","(the,8)","...
# 29415   {"(webroot,12)","(fix,5)","(@,5)","(file,5)","...
# 29412   {"(samsung,10)","(galaxy,8)","(balance,6)","(s...
# 81935   {"(issa,22)","(“,14)","(”,14)","(levin,11)","(...
# 81951   {"(the,7)","(house,6)","(annapolis,4)","(princ...
# 139357  {"(’,11)","(%,7)","(wine,7)","(abv,5)","(;,5)"...
# 119870  {"(beckham,4)","(son,4)","(he,4)","(’,4)","(ha...
# 139350  {"(’,18)","(“,13)","(bush,13)","(”,13)","(pres...
# 29399   {"(``,11)","('',11)","(richard,9)","(silicon,8...
# 29398   {"(i,8)","(subscribe,5)","(season,5)","(us,5)"...
# 29395   {"(samsung,10)","(galaxy,8)","(balance,6)","(s...
# 29394   {"(i,8)","(subscribe,5)","(season,5)","(us,5)"...
# 119869  {"(boyle,14)","(say,8)","(’,8)","(wife,8)","(“...
# 119868  {"(’,17)","(:,16)","(the,14)","(new,10)","(hor...
# 139342  {"(columbus,12)","(precourt,8)","(stadium,8)",...
# 29387   {"(webroot,12)","(fix,5)","(@,5)","(file,5)","...
# 81986   {"(’,5)","(–,4)","(newton-john,4)","(sky,3)","...
# 29383   {"(power,17)","(uk,12)","(coal,12)","(%,8)","(...
# 81993   {"(photo,7)","(’,6)","(five,4)","(world,4)","(...
# 139336  {"(thor,4)","(hiddleston,3)","(play,3)","(male...
# 82004   {"(@,22)","(covfefe,18)","(tweet,9)","(twitter...
# ...                                                   ...
# 52708   {"(’,16)","(corbyn,14)","(“,13)","(:,12)","(”,...
# 52687   {"(’,16)","(corbyn,14)","(“,13)","(:,12)","(”,...
# 99395   {"(hiv,12)","(california,7)","(time,7)","(brow...
# 147960  {"(’,11)","(the,7)","(state,6)","(“,4)","(”,4)...
# 158027  {"(’,13)","(”,9)","(“,9)","(party,7)","(invite...
# 99397   {"(macron,13)","(“,9)","(’,9)","(”,9)","(merke...
# 147963  {"(manafort,16)","(gate,16)","(the,13)","(firm...
# 99399   {"(“,30)","(schulz,25)","(”,24)","(’,24)","(sa...
# 147967  {"(manafort,20)","(’,13)","(he,9)","(political...
# 133239  {"(election,6)","(political,6)","(``,5)","('',...
# 133237  {"(election,6)","(political,6)","(``,5)","('',...
# 99405   {"(’,89)","(dent,81)","(“,52)","(”,52)","(trum...
# 99408   {"(“,21)","(’,21)","(”,21)","(say,14)","(macro...
# 99410   {"(’,30)","(dent,14)","(“,10)","(”,10)","(i,8)...
# 99412   {"(macron,13)","(“,9)","(’,9)","(”,9)","(merke...
# 99413   {"(’,30)","(dent,14)","(“,10)","(”,10)","(i,8)...
# 99416   {"(’,30)","(dent,14)","(“,10)","(”,10)","(i,8)...
# 99418   {"(’,32)","(“,17)","(”,17)","(macron,16)","(me...
# 128042  {"(’,16)","(“,16)","(”,16)","(obama,14)","(cam...
# 128043  {"(’,20)","(abe,17)","(party,9)","(percent,9)"...
# 158008  {"(brazile,7)","(clinton,5)","(``,5)","('',5)"...
# 99420   {"(’,32)","(“,17)","(”,17)","(macron,16)","(me...
# 133224  {"(space,9)","(nasa,4)","(chinese,3)","(expres...
# 99425   {"(’,32)","(“,17)","(”,17)","(macron,16)","(me...
# 158004  {"(anthem,12)","(national,11)","(kong,8)","(ho...
# 99426   {"(’,32)","(“,17)","(”,17)","(macron,16)","(me...
# 99429   {"(“,10)","(eurozone,10)","(”,10)","(european,...
# 147992  {"(’,75)","(manafort,58)","(“,39)","(”,38)","(...
# 21379   {"(election,9)","(``,9)","('',9)","(say,9)","(...
# 41664   {"(“,7)","(schumer,6)","(say,6)","(”,6)","(—,5...
#
#                                            named_entities lexical_diversity  \
# 62246   {"(\"Big Island\",LOCATION)","(Pele,PERSON)","...         79.000000
# 81906   {"(NBC,ORGANIZATION)","(\"New York\",LOCATION)...         68.393782
# 81911   {"(\"The Washington Post\",ORGANIZATION)","(Fa...         58.997050
# 126119  {"(Amazon,ORGANIZATION)","(Arkansas,LOCATION)"...         63.909774
# 29425   {"(Caliban,PERSON)","(Babylon,LOCATION)","(\"A...         76.515152
# 139377  {"(\"United States\",LOCATION)","(\"Major Leag...         63.720930
# 119878  {"(\"Selena Quintanilla-Pérez\",PERSON)","(Goo...         76.699029
# 81923   {"(\"Rick Foucheux\",PERSON)","(Shakespeare,PE...         77.400000
# 139373  {"(\"Megyn Kelly\",PERSON)","(\"Fox News\",ORG...         66.310160
# 29416   {"(\"Silicon Valley\",LOCATION)","(\"Richard H...         70.319635
# 29415   {"(Webroot,ORGANIZATION)","(Microsoft,ORGANIZA...         71.548117
# 29412   {"(Samsung,ORGANIZATION)","(Samsung,ORGANIZATI...         64.583333
# 81935   {"(\"Darrell Issa\",PERSON)","(Vista,LOCATION)...         57.276995
# 81951   {"(\"Prince George St.\",LOCATION)","(Annapoli...         78.260870
# 139357  {"(\"Ramón Bilbao Rioja Viñedos\",ORGANIZATION...         73.566879
# 119870  {"(Giants,ORGANIZATION)","(\"Odell Beckham\",P...         72.093023
# 139350  {"(\"Jordana Grolnick\",PERSON)","(Deadspin,PE...         61.431412
# 29399   {"(\"Silicon Valley\",LOCATION)","(UK,LOCATION...         70.329670
# 29398   {"(Caliban,PERSON)","(Babylon,LOCATION)","(\"A...         76.515152
# 29395   {"(Samsung,ORGANIZATION)","(Samsung,ORGANIZATI...         64.583333
# 29394   {"(Caliban,PERSON)","(Babylon,LOCATION)","(\"A...         76.833977
# 119869  {"(\"Joshua Boyle\",PERSON)","(Toronto,LOCATIO...         63.696370
# 119868  {"(USA,LOCATION)","(Derry,LOCATION)","(\"Brook...         72.004608
# 139342  {"(\"Precourt Sports Ventures Considering Relo...         61.437908
# 29387   {"(Webroot,ORGANIZATION)","(Microsoft,ORGANIZA...         72.222222
# 81986   {"(\"Amy Sky\",PERSON)","(Nashville,LOCATION)"...         87.777778
# 29383   {"(London,LOCATION)","(London,LOCATION)","(UK,...         68.361582
# 81993   {"(US,LOCATION)","(\"Donald Trump\",PERSON)","...         71.505376
# 139336  {"(Thor,PERSON)","(\"Kenneth Branagh\",PERSON)...         87.857143
# 82004   {"(US,LOCATION)","(Washington,LOCATION)","(\"D...         67.796610
# ...                                                   ...               ...
# 52708   {"(\"Jeremy Corbyn\",PERSON)","(Rotherham,LOCA...         58.660508
# 52687   {"(\"Jeremy Corbyn\",PERSON)","(Rotherham,LOCA...         58.660508
# 99395   {"(California,LOCATION)","(\"Jerry Brown\",PER...         64.848485
# 147960  {"(\"United States—scale\",LOCATION)","(Americ...         74.603175
# 158027  {"(\"Shari Weiss\",PERSON)","(\"Kris Jenner\",...         66.780822
# 99397   {"(BERLIN,LOCATION)","(Reuters,ORGANIZATION)",...         68.041237
# 147963  {"(WASHINGTON,LOCATION)","(\"Donald Trump\",PE...         58.540925
# 99399   {"(PARIS,LOCATION)","(\"Martin Schulz\",PERSON...         56.313498
# 147967  {"(\"Paul Manafort\",PERSON)","(\"Rick Gates\"...         71.790541
# 133239  {"(Russia,LOCATION)","(US,LOCATION)","(Google,...         76.579926
# 133237  {"(Russia,LOCATION)","(US,LOCATION)","(Google,...         77.007299
# 99405   {"(Hershey,LOCATION)","(Pennsylvania,LOCATION)...         52.019002
# 99408   {"(\"Emmanuel Macron\",PERSON)","(\"European U...         64.805415
# 99410   {"(Congress,ORGANIZATION)","(Trumpsanity,PERSO...         70.696721
# 99412   {"(BERLIN,LOCATION)","(Reuters,ORGANIZATION)",...         68.041237
# 99413   {"(Congress,ORGANIZATION)","(Trumpsanity,PERSO...         70.696721
# 99416   {"(Congress,ORGANIZATION)","(Trumpsanity,PERSO...         70.696721
# 99418   {"(\"Emmanuel Macron\",PERSON)","(France,LOCAT...         60.983264
# 128042  {"(RICHMOND,LOCATION)","(Obama,PERSON)","(\"Ba...         67.647059
# 128043  {"(\"Shinzo Abe\",PERSON)","(Japan,LOCATION)",...         72.629696
# 158008  {"(WASHINGTON,LOCATION)","(\"Democratic Nation...         72.588832
# 99420   {"(\"Emmanuel Macron\",PERSON)","(France,LOCAT...         60.983264
# 133224  {"(\"Soviet Union\",LOCATION)","(Sputnik,ORGAN...         76.649746
# 99425   {"(\"Emmanuel Macron\",PERSON)","(France,LOCAT...         60.983264
# 158004  {"(China,LOCATION)","(\"Beijing Exhibition Hal...         65.040650
# 99426   {"(\"Emmanuel Macron\",PERSON)","(France,LOCAT...         60.983264
# 99429   {"(\"Emmanuel Macron\",PERSON)","(Europe,LOCAT...         60.599078
# 147992  {"(\"Paul Manafort\",PERSON)","(Ukraine,LOCATI...         50.674274
# 21379   {"(\"Theresa May\",PERSON)","(\"General Electi...         66.666667
# 41664   {"(Senate,ORGANIZATION)","(\"Chuck Schumer\",P...         67.241379
#
#                                           sentiment_score binary_sentiment  \
# 62246   {"neg": 0.10356249999999999, "neu": 0.8581875,...                0
# 81906   {"neg": 0.05311111111111111, "neu": 0.80666666...                1
# 81911   {"neg": 0.07734374999999999, "neu": 0.78309374...                1
# 126119  {"neg": 0.008473684210526316, "neu": 0.9254736...                1
# 29425   {"neg": 0.040952380952380955, "neu": 0.8953333...                1
# 139377  {"neg": 0.040315789473684215, "neu": 0.8589122...                1
# 119878  {"neg": 0.012374999999999999, "neu": 0.8358750...                1
# 81923   {"neg": 0.07176666666666667, "neu": 0.85643333...                1
# 139373  {"neg": 0.06487234042553192, "neu": 0.85585106...                1
# 29416   {"neg": 0.07412820512820516, "neu": 0.81594871...                1
# 29415   {"neg": 0.06745000000000001, "neu": 0.89689999...                0
# 29412   {"neg": 0.0633125, "neu": 0.8603750000000001, ...                1
# 147992  {"neg": 0.08973026315789476, "neu": 0.85855921...                0
# 21379   {"neg": 0.06495238095238094, "neu": 0.81476190...                1
# 41664   {"neg": 0.0217, "neu": 0.8632, "pos": 0.115100...                1
#
#         cluster_label
# 62246               0
# 81906               0
# 81911               0
# 126119              0
# 29425               0
# 139377              0
# 119878              0
# 81923               0
# 139373              0
# 29416               0
# 29415               0
# 29412               0
# 81935               0
# 81951               0
# 139357              0
# 119870              0
# 139350              0
# 29399               0
# 29398               0
# 29395               0
# 29394               0
# 119869              0
# 119868              0
# 139342              0
# 29387               0
# 81986               0
# 29383               0
# 81993               0
# 139336              0
# 82004               0
# ...               ...
# 52708              14
# 52687              14
# 99395              14
# 147960             14
# 158027             14
# 99397              14
# 147963             14
# 99399              14
# 147967             14
# 133239             14
# 133237             14
# 99405              14
# 99408              14
# 99410              14
# 99412              14
# 99413              14
# 99416              14
# 99418              14
# 128042             14
# 128043             14
# 158008             14
# 99420              14
# 133224             14
# 99425              14
# 158004             14
# 99426              14
# 99429              14
# 147992             14
# 21379              14
# 41664              14
#
# [164541 rows x 21 columns]

# %%
clusters = {}
for i, row in data.iterrows():
    if row['cluster_label'] not in clusters:
        #print(row['body'])
        #print(row['url'])
        #print(row['id'])
        #print(row['title'])
        # add empty list for IDs for a preview 
        clusters[row['cluster_label']] = []

# %%
for cluster_val in clusters:
    for i, row in data.iterrows():
        if row['cluster_label'] is cluster_val:
            clusters[cluster_val].append(row['title'])

# %%
for cluster in clusters:
    print('\n')
    print(cluster)
    print(clusters[cluster][:25])
    print('\n')
# Out:
# 13
# ['London shows the challenge of preventing low-tech terror', "How To Help London Terrorist Attack Victims' Families", 'London attack: Raids across UK as Westminster attacker identified', 'July 7 2005 London Bombings Fast Facts', 'London unites against terror in defiant vigil', 'London attack: Khalid Masood', 'Tennessee Amber Alert: Ex-teacher accused of kidnapping reportedly spotted in Texas', 'Off-duty Indiana trooper saves couple from fire at home', 'Illegal Immigrant Accused of Murdering Teacher', 'Westminster Attack Victim Aysha Frade ‘Was Picking Up Her Children from School’ when Terrorist Took Her Life', 'Police Constable and Army Veteran Keith Palmer Was ‘Every Inch a Hero’', 'London Terror Killer Named as Convicted Criminal Khalid Masood', 'Italy: ‘North African’ Arrested After Driving at Police, Stabbing Officer', 'Reports: Israeli-American Teen Arrested for Antisemitic Hate Crime Hoax Spree', 'Westminster Attack Victim Aysha Frade ‘Was Picking Up Her Children from School’ when Terrorist Took Her Life', 'Reports: Israeli-American Teen Arrested for Antisemitic Hate Crime Hoax Spree', 'Four-Time Deported MS-13 Gang Member Charged in Child Rape, Stabbing 2 Women', 'Four-Time Deported MS-13 Gang Member Charged in Child Rape, Stabbing 2 Women', 'Illegal Immigrant Accused of Murdering Teacher', 'London Terror Killer Named as Convicted Criminal Khalid Masood', 'DELINGPOLE: Keep Calm And Carry On In The Face Of Muslim Terror?', 'Italy: ‘North African’ Arrested After Driving at Police, Stabbing Officer', 'Police Constable and Army Veteran Keith Palmer Was ‘Every Inch a Hero’', 'DELINGPOLE: Keep Calm And Carry On In The Face Of Muslim Terror?', 'London Attack Sparks Calls for Revamped Security of Aging U.K. Parliament']
#
#
#
#
# 0
# ["Belfast pubs: Inspiration behind the world's best bar", 'Weather', "'Power Rangers' lacks power in big-screen transformation", 'Great Barrier Reef with David Attenborough', 'The writing on the wall', 'More than 200 migrants feared drowned in Mediterranean', "Eurovision: Russia rejects offer for Julia Samoilova to perform 'via satellite'", "Gwyneth Paltrow won't eat an octopus because it's 'too smart to be food'", "Heineken fights back against Hungary's proposed ban on its red star logo", 'Kyle Larson Looks to Get Over the Hump at Fontana', 'Twitter Using Watson A.I. to Crack Down on ‘Abuse’', 'Dave Chappelle Accused of Making ‘Homophobic, Transphobic’ Jokes in Netflix Specials', 'Kristi Yamaguchi Tells Nancy Kerrigan to ‘Break A Leg,’ Twitter Reacts Accordingly', 'Jim Ross’ Wife Jan, 55, Dies From Injuries Sustained In Vespa Accident', 'Breitbart News Daily: Ryancare on Ice', 'Amy Schumer Exits ‘Barbie’ Movie', 'Kristi Yamaguchi Tells Nancy Kerrigan to ‘Break A Leg,’ Twitter Reacts Accordingly', 'Breitbart News Daily: Ryancare on Ice', 'Jim Ross’ Wife Jan, 55, Dies From Injuries Sustained In Vespa Accident', 'NFL Commish Goodell ‘Fine’ with Trump’s Kaepernick Comments', 'Dave Chappelle Accused of Making ‘Homophobic, Transphobic’ Jokes in Netflix Specials', 'Twitter Using Watson A.I. to Crack Down on ‘Abuse’', "VIDEO: U.S. Navy Tests 'Star Wars' Electromagnetic Rail Gun", 'Mother Beats Cancer During Pregnancy with Twins Only to Die from Heart Failure a Day After Giving Birth', 'NFL Commish Goodell ‘Fine’ with Trump’s Kaepernick Comments']
#
#
#
#
# 5
# ['Hospital Prices No Longer Secret As New Data Reveals Bewildering System, Staggering Cost Differences', 'How Diverse Is Your School?', 'DOJ highlights immigration arrests in statistics report', "Analysis: Don't bet on London attacker being lone wolf", 'Immigration: 300 billionaires live outside their home country', 'London attacks: How is security organised at other seats of power?', "ISIS' next steps after Mosul fight", "This Is What's at the Heart of the GOP Split on Republican Health Care Plan ...", 'Hampshire College Student Accused of Assaulting Basketball Player for Wearing Hair Braids, Claims ‘Cultural Appropriation’', 'Maryland High School Becomes Flashpoint in Immigration Debate After Police Arrest Illegal Aliens on Rape Charges', 'Watch: CNN’s Ham, Cuomo Get in Heated Health Care Debate', 'Graham: I’ll Do ‘Whatever It Takes’ to Get Gorsuch Confirmed, If Dems Filibuster, ‘We Would Have to Change the Rules’', 'Report: Transgender Activists Attack Pro-Family Campaign Bus With Hammer, Paint', 'Australian Minister: London Attack Shows We Were Right to Reject 500 Asylum Seekers', "Mattis on Iraq: 'I Don't See Any Reason to Pull Out Again and Find the Same Lesson'", 'Watch: CNN’s Ham, Cuomo Get in Heated Health Care Debate', 'Second Mexican Journalist Murdered in One Week, Juarez Cartel Implicated', 'L.A. Sheriff Faces Protests for Opposition to ‘Sanctuary State’', 'Gorka: An Upstanding Citizen or Immigrant on Monday Doesn’t Decide to Become a Jihadi
to Prevent Teams from Using Penalties to Control the Clock', 'The NHL Is Headed to China', 'Game of Thrones: Davos Actor on Spoilers', 'Game of Thrones: Jaime Actor on Melting Ice Facebook Video', 'Top 10 secrets casinos don’t want you to know', '‘For Honor’ Players Discover All Unlocks Would Cost over $700 – or 2.5 Years of Playtime', '‘For Honor’ Players Discover All Unlocks Would Cost over $700 – or 2.5 Years of Playtime', 'Horror Game ‘Outlast 2’ No Longer Banned in Australia', 'Horror Game ‘Outlast 2’ No Longer Banned in Australia', 'Brady Aiken Rejected $5M and Got Hurt; Now Past No. 1 Pick Fights for MLB Future', "Ichiro Wants to Play Until He's 50; Says He'll 'Just Die' After Retiring", 'MSU-Mankato Pitcher Tosses Shutout Day After Mom’s Death From Cancer', "LeBron James Passes Shaquille O'Neal for 7th on NBA's All-Time Scoring List", "Pot is legal in Nevada, but you can't get it on the Vegas Strip", "Playing 'Tetris' after trauma may reduce bad flashbacks", 'Intel True VR shoots and scores with March Madness coverage', '‘For Honor’ Players Plan Boycott of Game']
#
#
#
#
# 6
# ['Obamacare repeal could cost the poor a third of their income', 'North Korea will launch another nuclear test in next few days, officials say', "Wall Street's Trump Trade Panic Is Now Already Over", 'Coulter to Trump: Get Back to Immigration, Trade, Infrastructure, Building a Wall', "Wall Street's Trump Trade Panic Is Now Already Over", 'Exclusive: USS Carl Vinson Shadowed by Russian, Chinese Spy Ships Near South Korea', 'Coulter to Trump: Get Back to Immigration, Trade, Infrastructure, Building a Wall', 'Exclusive: USS Carl Vinson Shadowed by Russian, Chinese Spy Ships Near South Korea', 'What the failed Obamacare repeal means for tax reform', 'Disney World, Universal Studios fight tax bills in Florida', 'U.S. Official: North Korea May Conduct Nuclear Test ‘as Early as the End of the Month’', 'U.S. Official: North Korea May Conduct Nuclear Test ‘as Early as the End of the Month’', 'Despite Failure of North Carolina Boycott, NCAA to Renew Game Ban Against Bathroom Bill', 'Despite Failure of North Carolina Boycott, NCAA to Renew Game Ban Against Bathroom Bill', 'Virgil: Like Reagan, Trump Can Bounce Back—and So Can His Agenda', 'Virgil: Like Reagan, Trump Can Bounce Back—and So Can His Agenda', 'After Healthcare Flop, White House Seeks Help From Congress on Tax', 'Paul Ryan: Failure of Obamacare Replacement Makes Tax Reform Harder', 'Paul Ryan: Failure of Obamacare Replacement Makes Tax Reform Harder', 'This New Tweak to the GOP Health Care Bill Will Make Medicare Less Stable', "AHCA: Donald Trump's Health Care Failure Hurts Tax Reform", 'This app wants to make filing your taxes easier', 'North Korean threat: Japan mulls more aggressive military stance', 'U.S. debt to double over the next 30 years', 'Kim Jong-nam: Malaysians stranded in North Korea return home']
#
#
#
#
# 2
# ['Twitter considers paid membership option', 'Eddie Stobart: Lorry firm targets £550m stock market listing', 'ISPs can now sell your browsing history without permission, thanks to these Senators', "Consumer Watchdog Says Amazon's List Prices Are Bogus", "The 'Impossible' Bleeding Veggie Burger Is About To Be Much Easier To Get", 'Boom lands $33 million to test supersonic aircraft', "Jay Z is a fan of Away's 'unbreakable' suitcases", "Jay Z is a fan of Away's 'unbreakable' suitcases", 'Twitter considers paid membership option', 'Twitter is trying to do something to boost its business, but is it too little too late?', 'Why this tiny house in Tokyo is a really big deal', 'American Airlines finally replacing ‘itchy’ uniforms after complaints', 'Jay Z to Produce Trayvon Martin Film and Documentary Series', 'Jay Z to Produce Trayvon Martin Film and Documentary Series', 'Pret A Manger to pay work experience teens after online criticism', "Ripoff Alert: World's Biggest Credit Score Agency Has Been Deceiving People", 'Big Oil could be ready for a big comeback', "Jeff Bezos passes Warren Buffett to become the world's second richest person", 'Earnings growth may be best since late 2011', 'Sears stock is up 50% in a week. What the heck is going on?', 'Smartphones may be to blame for unprecedented spike in pedestrian deaths', 'SpaceX makes history: It launched a used rocket and then brought it back to Earth', "Campaigners seek 'to sell US politicians' browsing data'", 'FCC pushes Lifeline broadband subsidy approval back to the states', 'How will ISPs collect and sell your browser history?']
#
#
#
#
# 12
# ["Call for 'decently paid' maternity leave", 'Women Are Still Terribly Underrepresented in Business and Politics', 'Senator Apologizes for Joke About Losing Mammogram Benefits', 'The cruel double standard that could save Obamacare', "Gwyneth Paltrow's Goop publishes advice on how to have casual sex", 'Gwyneth Paltrow Offers Tips on Achieving ‘Orgasm Equality’', 'Gwyneth Paltrow Offers Tips on Achieving ‘Orgasm Equality’', 'This Week in Health: Breast Implants, Cancer and Alcohol', '5 Things to Know About the Breast Implants Linked to a Rare Cancer', 'GOP Health Care Bill Would Require New Moms on Medicaid to Find Work 60 Days After Birth', 'This Week in Motto: The Joys and Challenges of Motherhood', 'HIV: What Women Need to Know', 'Mourners pack church, streets for medic struck by ambulance', 'Jewelry store billboard faces backlash for message encouraging violence', 'Cecile Richards Credits Planned Parenthood Supporters with Stopping AHCA', 'Cecile Richards Credits Planned Parenthood Supporters with Stopping AHCA', "Why India's new maternity leave policy may be bad for women", "U.S. women's hockey team will sit out world championships in pay protest", 'St. Charles Man Honored For Saving Woman During Domestic Attack', "#TBT: Margaret Chase Smith and her 'place in the sun'", "Study finds 'staggering' rise in mastectomies in these states", 'Oxford to show more portraits of women in diversity bid', "Are Mike Pence's dining habits chivalrous or sexist?", "'I was sterilised against my will'", "School apologises for 'slut-shame' prom posters about appropriate dresses"]
#
#
#
#
# 7
# ['Pro-settlement hardliner Friedman confirmed as US envoy to Israel', 'Third Victim of London Attack Named as American Tourist Kurt Cochran', 'Third Victim of London Attack Named as American Tourist Kurt Cochran', "Pearson boss sees pay boost despite firm's struggles", 'Trump blames Democrats for failed healthcare bill', "EU 'not in hostile mood' as Brexit talks beckon, says Juncker", "Chuck Schumer Breaks the Senate: Why Desperate Red-State Democrats Are Floating a 'Deal' to Let Gorsuch Through.", 'Dudley Says New York Fed Is Working to Improve Cyberdefenses', 'Hong Kong election: Beijing-backed Lam first female leader', 'The wine detective battling counterfeiters', "US hiker given warning for rescuing 'abandoned' bear cub", 'Kilted yoga star targeted by homophobic hate mail', "South Africa's President Zuma sacks finance minister", 'Fired Trump aide Michael Flynn wants immunity to testify on Russia allegations', 'Removing Assad no longer a priority', 'Fired Trump aide Michael Flynn wants immunity to testify on Russia allegations', "Mr. T on faith: 'I answer only to God'", 'UK faces tough divorce from the EU', "Pamela Anderson's 'love' for Julian Assange", "Reckitt Benckiser slashes boss's pay by 40%", "Brexit: Government 'to stand up' for Gibraltar's interests", 'Gilbert Baker, LGBT rainbow flag creator, dies aged 65', 'Venezuela moves to defuse Supreme Court powers dispute', 'Great-grandma and cat survive five days in Colorado wilderness', "Tales of deportation in Trump's America: Week Three"]
#
#
#
#
# 10
# ["Why Apple's red iPhones are not 'Red' in China", 'Apple denied the massive iCloud hack (but you should still change your password)', 'Google and Facebook Are Responsible for Extremist Content: Sir Martin Sorrell', 'Best Tablets for $300 or Less', 'More Big Brands Pull Ads From YouTube in Widening Boycott', "Apple says CIA's arsenal of iPhone and Mac exploits is outdated", 'What the Samsung Galaxy S8 means for the iPhone 8', 'Fmr. Apple CEO John Sculley: Made in USA iPhone Not Practical Right Now', 'How to safeguard your data at the US border', 'Your next Android phone -- Samsung Galaxy S8 or Google Pixel?', 'iPhone 8 leak reveals surprising design, new name', 'The smartphone is eventually going to die, and then things are going to get really crazy', "Samsung's Galaxy S8 could make the future of headphones messier", 'Samsung removes the physical home button: The Galaxy S8 is better as a result', 'Google News', 'Samsung is spending $9 billion on the iPhone', "Google tweaks the Pixel C's interface to match its smartphones", 'Android 7.1.2 Nougat Now Rolling Out To Pixel C, Nexus Player: Last Update Before Android O?', 'Android update makes Google’s Pixel C look more like its Pixel smartphones', 'Commentary: As smartphone prices rise, ‘super’ sales for Apple’s iPhone aren’t such a sure thing', 'The Galaxy S8, S8 Plus Won’t Support Google’s Daydream VR', 'Three New Apple Ads Again Claim iPad Pro Is Better Than Laptops', "Galaxy S8 Plus Vs Galaxy S7 Edge: What's The Difference?", 'Google News', 'Report: Next iPhone models to include True Tone displays, custom front/back 3D sensors for facial recognition & AR']
#
#
#
#
# 3
# ['CNBC: Facebook Could ‘Learn’ About ‘Fighting Fake News’ From Chinese Social Media', 'CNBC: Facebook Could ‘Learn’ About ‘Fighting Fake News’ From Chinese Social Media', 'What Employers Look For On Social Media Profiles', 'Hate Speech: Anti-Semitic Message Shared Every 83 Seconds', "Harry Potter festival plans 'blown out of the water'", 'Mom shares heartbreaking photo of 10-year-old son fighting cancer', 'Facebook Failed to Protect 30 Million Users From Having Their Data Harvested by Trump Campaign Affiliate', 'Counterfeit tobacco and cigarettes sold on Facebook', 'Teenager arrested over live-streamed Chicago sex attack', 'Are you worried about your data privacy? You should care more about Google than Comcast.', '14-Year-Old Charged In Sexual Assault Broadcast On Facebook Live', 'Google News', 'Youth arrested in sexual assault of Chicago teen seen on Facebook Live', 'Students Rally to Reinstate Teacher Suspended for Sexy Selfies', 'Snapchat brings search to Stories', 'Would you pay for online privacy?', 'Google News', "Boy or Girl? Text Alerts to Deliver Gender of April the Giraffe's Calf", 'Tehran fire: dozens of firefighters feared dead as tower collapses', 'Only Fools and Horses USA – and other failed TV remakes', 'Snapchat brings search to Stories', 'Would you pay for online privacy?', 'Snapchat makes its stories searchable', '$14M initiative to fight fake news includes Facebook, Mozilla', 'Nivea Pulls ‘White Is Purity’ Ad After Backlash']
